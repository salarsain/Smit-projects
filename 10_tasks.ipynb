# %%
marks = int(input("Enter your marks (out of 100): "))

if marks >= 90:
    print("Topper of the class 🎓")
elif 75 <= marks <= 89:
    print("Excellent effort 💪")
elif 50 <= marks <= 74:
    print("Keep improving 📘")
else:
    print("Needs extra support 📉")
# Out:
# Topper of the class 🎓

# %%
choice = int(input("Enter your choice (1: Tea, 2: Coffee, 3: Hot Chocolate): "))

if choice == 1:
    print("Here’s your Tea 🍵")
elif choice == 2:
    print("Here’s your Coffee ☕")
elif choice == 3:
    print("Hot Chocolate coming up 🍫")
else:
    print("Invalid selection ❌")
# Out:
# Here’s your Coffee ☕

# %%
color = input("Enter traffic light color (red, yellow, green): ").lower()

if color == "red":
    print("STOP 🚫")
elif color == "yellow":
    print("READY ⚠")
elif color == "green":
    print("GO ✅")
else:
    print("Signal malfunction 🚨")
# Out:
# Signal malfunction 🚨

# %%
age = int(input("Enter your age: "))
height = int(input("Enter your height in cm: "))

if age >= 12 and height >= 120:
    print("You can ride 🎡")
elif age < 12:
    print("Too young 🙅")
elif height < 120:
    print("Too short for safety 🚷")
# Out:
# Too short for safety 🚷

# %%
size = input("Enter pizza size (small, medium, large): ").lower()
coupon = input("Do you have a coupon? (yes/no): ").lower()

if size == "large" and coupon == "yes":
    print("20% discount applied 🍕")
elif size == "medium":
    print("10% discount applied 🍕")
elif size == "small":
    print("5% discount applied 🍕")
else:
    print("Invalid size!")
# Out:
# 5% discount applied 🍕

# %%
pin = int(input("Enter your PIN: "))
balance = float(input("Enter your balance: "))

if pin == 1234:
    if balance >= 500:
        print("Withdrawal successful 💸")
    else:
        print("Insufficient funds 💰")
else:
    print("Incorrect PIN 🔒")
# Out:
# Incorrect PIN 🔒

# %%
season = input("Enter season (summer, winter, spring, autumn): ").lower()

if season == "summer":
    print("Go to the beach 🏖")
elif season == "winter":
    print("Let’s hit the mountains 🏔")
elif season == "spring":
    print("Visit the gardens 🌸")
elif season == "autumn":
    print("Take a forest hike 🍂")
else:
    print("Invalid season entered.")
# Out:
# Visit the gardens 🌸

# %%
speed = int(input("Enter your speed (km/h): "))

if speed < 40:
    print("Too slow, keep moving 🐢")
elif 40 <= speed <= 80:
    print("Safe speed 🚗")
elif 81 <= speed <= 120:
    print("Warning! Overspeed ⚠")
else:
    print("License suspended 🚓")
# Out:
# Safe speed 🚗

# %%
nights = int(input("Enter number of nights: "))
room_type = input("Enter room type (standard, deluxe, suite): ").lower()

if room_type == "suite" and nights >= 3:
    print("Luxury discount applied 🏆")
elif room_type == "deluxe":
    print("Breakfast included 🍳")
elif room_type == "standard":
    print("Basic stay 🛏")
else:
    print("Invalid room type.")
# Out:
# Basic stay 🛏

# %%
score = int(input("Enter your score: "))
coins = int(input("Enter number of coins: "))

if score >= 1000 and coins >= 50:
    print("Next Level Unlocked 🎮")
elif score >= 500:
    print("Halfway there 🔥")
else:
    print("Keep playing 💪")
# Out:
# Keep playing 💪

# %%
# --- Part 1: Salary Checker ---
salary = float(input("Enter your salary: "))

if salary > 100000:
    print("High Income")
elif 50000 <= salary <= 100000:
    print("Medium Income")
else:
    print("Low Income")

print("----------------------------------")

# --- Part 2: Temperature Checker ---
temperature = float(input("Enter temperature in Celsius: "))

if temperature > 40:
    print("Very Hot")
elif 25 <= temperature <= 40:
    print("Moderate")
else:
    print("Cold")

print("----------------------------------")

# --- Part 3: Simple ATM Simulation ---
correct_pin = 1234  # You can change this as needed
balance = 50000     # Example balance

pin = int(input("Enter your ATM PIN: "))

if pin == correct_pin:
    print("PIN accepted ✅")
    print(f"Your current balance is: Rs. {balance}")
else:
    print("Error: Incorrect PIN ❌")
# Out:
# Low Income
# ----------------------------------
# Cold
# ----------------------------------
# PIN accepted ✅
# Your current balance is: Rs. 50000

# %%
# ATM Program with Deposit, Withdrawal, Balance & Transaction History

# Initialize user details
user_name = input("Enter your name: ")
pin = int(input("Set your 4-digit PIN: "))
balance = 0
transaction_history = []

print(f"\nWelcome {user_name} to the ATM!\n")

while True:
    print("\nSelect an option:")
    print("1. Deposit")
    print("2. Withdraw")
    print("3. Check Balance")
    print("4. Transaction History")
    print("5. Exit")
    
    choice = input("Enter your choice (1-5): ")
    
    if choice == "1":
        deposit_amount = float(input("Enter amount to deposit: "))
        if deposit_amount > 0:
            balance += deposit_amount
            transaction_history.append(f"Deposited: ${deposit_amount:.2f}")
            print(f"Successfully deposited ${deposit_amount:.2f}")
        else:
            print("Invalid amount! ❌")
    
    elif choice == "2":
        entered_pin = int(input("Enter your PIN to withdraw: "))
        if entered_pin == pin:
            withdraw_amount = float(input("Enter amount to withdraw: "))
            if withdraw_amount <= balance and withdraw_amount > 0:
                balance -= withdraw_amount
                transaction_history.append(f"Withdrawn: ${withdraw_amount:.2f}")
                print(f"Successfully withdrawn ${withdraw_amount:.2f}")
            else:
                print("Insufficient funds or invalid amount! 💰")
        else:
            print("Incorrect PIN! 🔒")
    
    elif choice == "3":
        print(f"Your current balance is: ${balance:.2f}")
    
    elif choice == "4":
        if transaction_history:
            print("\nTransaction History:")
            for transaction in transaction_history:
                print(transaction)
        else:
            print("No transactions yet.")
    
    elif choice == "5":
        print(f"Thank you {user_name} for using our ATM. Goodbye! 👋")
        break
    
    else:
        print("Invalid option, please try again! ❌")
# Out:
# Welcome salar to the ATM!
#
#
# Select an option:
# 1. Deposit
# 2. Withdraw
# 3. Check Balance
# 4. Transaction History
# 5. Exit
# Your current balance is: $0.00
#
# Select an option:
# 1. Deposit
# 2. Withdraw
# 3. Check Balance
# 4. Transaction History
# 5. Exit
# Successfully deposited $20000.00
#
# Select an option:
# 1. Deposit
# 2. Withdraw
# 3. Check Balance
# 4. Transaction History
# 5. Exit
# Your current balance is: $20000.00
#
# Select an option:
# 1. Deposit
# 2. Withdraw
# 3. Check Balance
# 4. Transaction History
# 5. Exit
#
# Transaction History:
# Deposited: $20000.00
#
# Select an option:
# 1. Deposit
# 2. Withdraw
# 3. Check Balance
# 4. Transaction History
# 5. Exit
# Thank you salar for using our ATM. Goodbye! 👋
